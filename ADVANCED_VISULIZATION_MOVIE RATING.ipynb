# %%
# MOVIE RATING ANALYTICS (ADVANCED VISULIZATION)

import pandas as pd
import os

# %%
os.getcwd() # if you want to change the working directory
# Out:
# 'c:\\Users\\admin\\vscode project\\seaborn\\ADVANCED_VISULIZATION_MOVIE RATING'

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
movies = pd.read_csv(r'C:\Users\admin\vscode project\seaborn\ADVANCED_VISULIZATION_MOVIE RATING\Movierating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRatings', 'AudienceRatings','Budgetinmillion', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetinmillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# 4               20  2009

# %%
movies.shape
# Out:
# (559, 6)

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  Budgetinmillion         Year
# count     559.000000       559.000000       559.000000   559.000000
# mean       47.309481        58.744186        50.236136  2009.152057
# std        26.413091        16.826887        48.731817     1.362632
# min         0.000000         0.000000         0.000000  2007.000000
# 25%        25.000000        47.000000        20.000000  2008.000000
# 50%        46.000000        58.000000        35.000000  2009.000000
# 75%        70.000000        72.000000        65.000000  2010.000000
# max        97.000000        96.000000       300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budgetinmillion  559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film  = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budgetinmillion  559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre  = movies.Genre.astype('category')

# %%
movies.Year  = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budgetinmillion  559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
 # How to working with joint plots
from matplotlib import pyplot as plt # Visualization

# %%
import seaborn as sns # Advanced visulization
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Basically joint plot is a scatter plot & it find the relation between audience & critics
# Also if you look up you can find the uniform distubution(critics) and normal distrubution(audience)

# %%
j = sns.jointplot(data = movies, x = 'CriticRatings', y = 'AudienceRatings')
plt.show()

# Audience rating is more dominant then critics ratings
# Based on this we find out as most people are not likelihood to watch audience rating & less likely to watch critics rating
# there is positive corelation between 2 attributes
# let me explain the excel - if you filter audience rating &critic rating has very low

# %%
j = sns.jointplot(data = movies, x = 'CriticRatings', y = 'AudienceRatings', kind='hex')
plt.show()

# %%
#Histograms

# <<< chat1

m1 = sns.distplot(movies.AudienceRatings)
plt.show()

#y - axis generated by seaborn automatically that is the powefull of seaborn gallery

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRatings, bins = 15)
plt.show()

# %%
#sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRatings, bins=20)
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = plt.hist(movies.AudienceRatings, bins=20)
plt.show()

# %%
# <<< chat - 2

# Creating stacked histograms & this is bit tough to understand

# %%
#h1 = plt.hist(movies.Budgetinmillion)

plt.hist(movies.Budgetinmillion)
plt.show()

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budgetinmillion',
#        'Year'],
#       dtype='object')

# %%
plt.hist(movies[movies.Genre == 'Drama'].Budgetinmillion)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetinmillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# 4               20  2009

# %%
#movies.Genre.unique()

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movies[movies.Genre == 'Action'].Budgetinmillion, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].Budgetinmillion, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].Budgetinmillion, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].Budgetinmillion,\
          movies[movies.Genre == 'Drama'].Budgetinmillion, \
          movies[movies.Genre == 'Thriller'].Budgetinmillion, \
          movies[movies.Genre == 'Comedy'].Budgetinmillion],
         bins = 10, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRatings', y='AudienceRatings',fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRatings', y='AudienceRatings',fit_reg=False,hue = 'Genre')
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRatings', y='AudienceRatings',fit_reg=False,hue = 'Genre',aspect=1)
plt.show()

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot

# %%
k1 = sns.kdeplot (movies.CriticRatings)
plt.show()

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k2 = sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 k2 = sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#subplots

f, ax = plt.subplots(1,2, figsize =(12,6))
#f, ax = plt.subplots(3,3, figsize =(12,6))
plt.show()

# %%
#Box plots - 

w = sns.boxplot(data=movies, x='Genre', y = 'CriticRatings',hue='Genre')
plt.show()

# %%
#violin plot

z = sns.violinplot(data=movies, x='Genre', y = 'CriticRatings') 
plt.show()

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRatings')
plt.show()

# %%
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRatings')
plt.show()

# %%
# Createing a Facet grid
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots
plt.show()

# %%
plt.scatter(movies.CriticRatings,movies.AudienceRatings)
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings' ) #scatterplots are mapped in facetgrid
plt.show()

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'Budgetinmillion') #scatterplots are mapped in facetgrid
plt.show()

# %%
#
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings',**kws ) #scatterplots are mapped in facetgrid
plt.show()
